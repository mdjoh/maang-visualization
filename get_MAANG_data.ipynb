# %%
# Import necessary libraries
import pandas as pd
import pandas_datareader as pdr
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# Enable retrieved stock data to be stored in a pandas dataframe
yf.pdr_override()

# Download MAANG stock closing price data from Yahoo and store in a dataframe
stock_df = pdr.data.get_data_yahoo(["META", "AMZN", "AAPL", "NFLX", "GOOG"], start="2020-01-01", end="2023-12-31")["Close"]
stock_df
# Out:
# [*********************100%%**********************]  5 of 5 completed
# Ticker            AAPL        AMZN        GOOG        META        NFLX
# Date
# 2020-01-02   75.087502   94.900497   68.368500  209.779999  329.809998
# 2020-01-03   74.357498   93.748497   68.032997  208.669998  325.899994
# 2020-01-06   74.949997   95.143997   69.710503  212.600006  335.829987
# 2020-01-07   74.597504   95.343002   69.667000  213.059998  330.750000
# 2020-01-08   75.797501   94.598503   70.216003  215.220001  339.260010
# ...                ...         ...         ...         ...         ...
# 2023-12-22  193.600006  153.419998  142.720001  353.390015  486.760010
# 2023-12-26  193.050003  153.410004  142.820007  354.829987  491.190002
# 2023-12-27  193.149994  153.339996  141.440002  357.829987  491.790009
# 2023-12-28  193.580002  153.380005  141.279999  358.320007  490.510010
# 2023-12-29  192.529999  151.940002  140.929993  353.959991  486.880005
#
# [1006 rows x 5 columns]

# %%
# Write closing price data to csv for import into Tableau
stock_df.to_csv("MAANG_closing_price.csv")

# %%
# Plot closing price data for each stock for initial inspection
plt.figure(figsize=(15,10))
plt.plot(stock_df)
plt.title('MAANG Close Price History', fontsize=18)
plt.xlabel('Date', fontsize=16)
plt.ylabel('Stock Price ($)', fontsize=16)
plt.legend(["AAPL", "AMZN", "GOOG", "META", "NFLX"], loc='upper left')
